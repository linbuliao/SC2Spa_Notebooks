# %%
import pandas as pd
import numpy as np
import anndata as ad

import os

import matplotlib.pyplot as plt

# %%
t = !pwd
t = t[0]
# %cd /mnt/win1/
from DeepSIST import benchmarking
# %cd $t
# Out:
# /mnt/win1
# /mnt/win1/DeepSIST_Notebook/MouseHippocampus_SSV2/SI_Benchmarking

# %% [markdown]
# # Load

# %%
adata = ad.read_h5ad('../../Dataset/AdataMH1.h5ad')
adata.var_names_make_unique()

Y = adata.obs[['xcoord', 'ycoord']].values
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
pct_offset = 0

def MinMaxNorm(Y, Y_ref = Y):
    return (Y-Y_ref.min(axis = 0))/(Y_ref.max(axis = 0)-Y_ref.min(axis = 0))/(1+pct_offset)

def ReMMNorm(Y, Y_pred):
    return (Y_pred*(Y.max(axis=0)-Y.min(axis=0)*(1+pct_offset))+Y.min(axis = 0))

def PolarTrans(Y):
    
    R = np.sqrt(np.square(Y[:,0]) + np.square(Y[:,1]))
    Theta = np.arctan(Y[:,1]/Y[:,0])
    RTheta = np.concatenate([R.reshape(-1,1), Theta.reshape(-1,1)], axis = 1)
    
    return RTheta

def RePolarTrans(RTheta):
    x = RTheta[:,0] * np.cos(RTheta[:,1])
    y = RTheta[:,0] * np.sin(RTheta[:,1])
    Y = np.concatenate([x.reshape(-1,1), y.reshape(-1,1)], axis = 1)
    return Y

# %%
RTheta = PolarTrans(Y)
YNorm = MinMaxNorm(Y)

train_indices = []
test_indices = []

for i in range(5):
    train_index = pd.read_csv('../CV_groups/index_train_' + str(i+1) + '.csv',
                              header = None, index_col = 0).values.flatten()
    test_index = pd.read_csv('../CV_groups/index_test_' + str(i+1) + '.csv',
                             header = None, index_col = 0).values.flatten()
    train_indices.append(train_index)
    test_indices.append(test_index)

# %%
SpaOTscs = []
novosparcs = []
DSs = []
LRs = []
Tangrams = []

#Preprocess (format transform and normalize)
for i in range(5):
    
    Tangram = pd.read_csv('Tangram/pred_' + str(i) + '.csv').values
    SpaOTsc = pd.read_csv('SpaOTsc/pred_' + str(i) + '.csv').values
    novosparc = pd.read_csv('novosparc/pred_' + str(i) + '.csv').values
    DS = pd.read_csv('DeepSIST/pred_' + str(i) + '.csv', header = None, index_col = 0).values
    LR = pd.read_csv('LR/pred_' + str(i) + '.csv', header = None, index_col = 0).values

    #Normalize
    DS = MinMaxNorm( RePolarTrans(ReMMNorm(RTheta, DS)), Y_ref = Y)
    LR = MinMaxNorm( RePolarTrans(ReMMNorm(RTheta, LR)), Y_ref = Y)
    novosparc = MinMaxNorm(novosparc, Y_ref = Y)
    SpaOTsc = MinMaxNorm(SpaOTsc, Y_ref = Y)
    Tangram = MinMaxNorm(Tangram, Y_ref = Y)

    Tangrams.append(Tangram)
    SpaOTscs.append(SpaOTsc)
    novosparcs.append(novosparc)
    DSs.append(DS)
    LRs.append(LR)

# %%
def evaluate(pred, Y_true):

    pearsonr_x = stats.pearsonr(Y_true[:, 0], pred[:, 0])[0]
    pearsonr_y = stats.pearsonr(Y_true[:, 1], pred[:, 1])[0]
    rmse = np.sqrt(np.square(Y_true - pred).sum() / Y_true.shape[0])
    r2 = r2_score(Y_true, pred, multioutput='variance_weighted')
    
    return [pearsonr_x, pearsonr_y, rmse, r2]

def eval_cv(preds, Y, test_indices):
    
    performances = []

    for i in range(5):
        performance = evaluate(pred = preds[i],
                               Y_true = Y[test_indices[i]])
        performances.append(performance)

    performances = pd.DataFrame(performances,
                                columns = ['pearsonr_x', 'pearsonr_y', 'MSE', 'R2'])
    
    return performances

# %%
Tangram_performance = benchmarking.eval_cv(Tangrams, YNorm, test_indices)
SpaOTsc_performance = benchmarking.eval_cv(SpaOTscs, YNorm, test_indices)
novo_performance = benchmarking.eval_cv(novosparcs, YNorm, test_indices)
DS_performance = benchmarking.eval_cv(DSs, YNorm, test_indices)
LR_performance = benchmarking.eval_cv(LRs, YNorm, test_indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29412/597160695.py in <module>
# ----> 1 Tangram_performance = benchmarking.eval_cv(Tangrams, YNorm, test_indices)
#       2 SpaOTsc_performance = benchmarking.eval_cv(SpaOTscs, YNorm, test_indices)
#       3 novo_performance = benchmarking.eval_cv(novosparcs, YNorm, test_indices)
#       4 DS_performance = benchmarking.eval_cv(DSs, YNorm, test_indices)
#       5 LR_performance = benchmarking.eval_cv(LRs, YNorm, test_indices)
#
# /mnt/win1/DeepSIST/benchmarking.py in eval_cv(preds, YNorm, test_indices)
#      21         performances.append(performance)
#      22
# ---> 23     performances = pd.DataFrame(performances,
#      24                                 columns = ['pearsonr_x', 'pearsonr_y', 'MSE', 'R2'])
#      25
#
# NameError: name 'pd' is not defined

# %%
Benchmark = pd.DataFrame([DS_performance.mean().tolist(),
                          Tangram_performance.mean().tolist(),
                          novo_performance.mean().tolist(),
                          SpaOTsc_performance.mean().tolist(),
                          LR_performance.mean().tolist()],
                          columns=['pearsonr_x', 'pearsonr_y', 'RMSE', 'R2'],
                          index = ['DeepSIST', 'Tangram', 'Novosparc', 'SpaOTsc', 'LR'])
for column in Benchmark.columns:
    Benchmark[column] = Benchmark[column].apply('{:,.3f}'.format)
Benchmark.to_csv('Benchmark.csv', header = True, index = True)
Benchmark
# Out:
#           pearsonr_x pearsonr_y   RMSE      R2
# DeepSIST       0.737      0.881  0.213   0.657
# Tangram        0.422      0.583  0.341   0.123
# Novosparc      0.519      0.662  0.325   0.206
# SpaOTsc        0.226      0.393  0.354   0.056
# LR             0.388      0.526  0.438  -0.447

# %% [markdown]
# # Visualization

# %%
adata = ad.read_h5ad('../AdataMH1.h5ad')
adata.var_names_make_unique()

Anno = pd.read_csv('../ssHippo_RCTD.csv', index_col = 0)

Anno['MCT'] = 't'

index1 = Anno.index[(Anno['celltype_1'] == Anno['celltype_2'])]
Anno['MCT'][index1] = Anno['celltype_1'][index1]
index2 = Anno.index[(Anno['celltype_1'] != Anno['celltype_2'])]
Anno['MCT'][index2] = (Anno['celltype_1'][index2] + '_' + Anno['celltype_2'][index2]).apply(lambda x: '_'.join(sorted(set(x.split('_')))))

adata.obs = adata.obs.merge(Anno, left_index = True, right_index = True, how = 'left')
adata.obs
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#                 xcoord  ycoord  n_genes  n_genes_by_counts  total_counts  \
# barcodes
# GTAAGTTGGCATGA  5524.7  2764.0     3429               3429        8230.0
# ATGGCAGTCCCGCC  5511.6  2814.2     3306               3304        7656.0
# TAAGCAACATTGAC  5473.3  2813.5     3139               3138        7523.0
# CTCCAGCCTTGCAT  3536.2  3484.7     2982               2980        8067.0
# GACCCGCGATGCCC  5428.8  4168.4     2869               2866        7824.0
# ...                ...     ...      ...                ...           ...
# CTGGCTTTAGACCT  2632.4  4150.5      128                128         143.0
# CACCCGATGACTCC  4314.4  1770.1      100                100         120.0
# CTTGATTAGGCAGG  1452.5  3013.1      108                108         127.0
# GAGTTCCTAAGCGG  3090.1  2045.0      103                103         114.0
# GCGCTCAGTGCTCT  3304.1  3491.5      112                112         115.0
#
#                 total_counts_mt  pct_counts_mt  total_counts_ERCC  \
# barcodes
# GTAAGTTGGCATGA            169.0       2.053463                1.0
# ATGGCAGTCCCGCC            212.0       2.769070                2.0
# TAAGCAACATTGAC            173.0       2.299614                0.0
# CTCCAGCCTTGCAT            569.0       7.053427                1.0
# GACCCGCGATGCCC            219.0       2.799080                2.0
# ...                         ...            ...                ...
# CTGGCTTTAGACCT              8.0       5.594406                0.0
# CACCCGATGACTCC              6.0       5.000000                0.0
# CTTGATTAGGCAGG             20.0      15.748032                0.0
# GAGTTCCTAAGCGG              6.0       5.263158                0.0
# GCGCTCAGTGCTCT              4.0       3.478261                0.0
#
#                 pct_counts_ERCC leiden       spot_class celltype_1 celltype_2  \
# barcodes
# GTAAGTTGGCATGA         0.012151      4          singlet      CA3Pc      CA3Pc
# ATGGCAGTCCCGCC         0.026123      4          singlet      CA3Pc      CA3Pc
# TAAGCAACATTGAC         0.000000      4  doublet_certain      CA3Pc          O
# CTCCAGCCTTGCAT         0.012396     12  doublet_certain          C          O
# GACCCGCGATGCCC         0.025562      6  doublet_certain          O         MM
# ...                         ...    ...              ...        ...        ...
# CTGGCTTTAGACCT         0.000000      9          singlet        DPc        DPc
# CACCCGATGACTCC         0.000000      5          singlet          O          O
# CTTGATTAGGCAGG         0.000000      1           reject         NS          A
# GAGTTCCTAAGCGG         0.000000      1           reject         Ec          O
# GCGCTCAGTGCTCT         0.000000      9           reject          I        DPc
#
#                     MCT
# barcodes
# GTAAGTTGGCATGA    CA3Pc
# ATGGCAGTCCCGCC    CA3Pc
# TAAGCAACATTGAC  CA3Pc_O
# CTCCAGCCTTGCAT      C_O
# GACCCGCGATGCCC     MM_O
# ...                 ...
# CTGGCTTTAGACCT      DPc
# CACCCGATGACTCC        O
# CTTGATTAGGCAGG     A_NS
# GAGTTCCTAAGCGG     Ec_O
# GCGCTCAGTGCTCT    DPc_I
#
# [35349 rows x 14 columns]

# %%
def Visualize_SSV2(adata, coord, ctname = 'MCT', anchor = (1, 0.9),
                   xlim = [650, 5750], ylim = [650, 5750], lim = False,
                   title = 'DeepSIST', legend = True):
    
    save = 'figures_SI/'
    if not os.path.exists(save):
        os.makedirs(save)
    
    CTs = adata.obs[ctname].value_counts()
    is_doub = CTs.index.str.contains('_')

    SelectedCTs = CTs[~is_doub].index.tolist()[:8]
    #SelectedCTs = CTs.index.tolist()[:8]

    t = adata
    Select1 = t.obs[ctname].apply(lambda x: x in SelectedCTs)
    Select = Select1
    t = t[Select]
    coord = coord[Select]

    color_dic = {}
    for i, ct in enumerate(t.obs[ctname].unique()):
        color_dic[ct] = i

    color = list(map(lambda x: color_dic[x], t.obs[ctname]))

    plt.figure(figsize =(7,6))
    scatter = plt.scatter(coord[:, 0],\
                coord[:, 1],\
                s = 3,\
                c = color,\
                cmap = plt.get_cmap('Paired'))
    plt.grid(False)
    
    if(lim):
        plt.xlim([650, 5750])
        plt.ylim([650, 5750])
    
    if(legend):
        plt.title(title)
        plt.legend(handles=scatter.legend_elements()[0],
                   labels = list(t.obs[ctname].unique()),
                   bbox_to_anchor=anchor)
        plt.savefig(save + title + '.png', bbox_inches='tight')
    else:
        plt.savefig(save + title + '_no_legend.png', bbox_inches='tight')
    
    plt.show()

# %%
i = 0
legend = False
index = test_indices[i]

Visualize_SSV2(adata = adata[index], coord = Y[index], title = 'Raw')
Visualize_SSV2(adata = adata[index], coord = Y[index], title = 'Raw', legend = legend)

DeepSIST = pd.read_csv('DeepSIST/pred_' + str(i) + '.csv', header = None, index_col = 0).values
DeepSIST = RePolarTrans(ReMMNorm(RTheta, DeepSIST))
Visualize_SSV2(adata = adata[index], coord = DeepSIST, title = 'DeepSIST')
Visualize_SSV2(adata = adata[index], coord = DeepSIST, title = 'DeepSIST', legend = legend)

Tangram = pd.read_csv('Tangram/pred_' + str(i) + '.csv').values
Visualize_SSV2(adata = adata[index], coord = Tangram, title = 'Tangram')
Visualize_SSV2(adata = adata[index], coord = Tangram, title = 'Tangram', legend = legend)

novosparc = pd.read_csv('novosparc/pred_' + str(i) + '.csv').values
Visualize_SSV2(adata = adata[index], coord = novosparc, title = 'Novosparc')
Visualize_SSV2(adata = adata[index], coord = novosparc, title = 'Novosparc', legend = legend)

SpaOTsc = pd.read_csv('SpaOTsc/pred_' + str(i) + '.csv').values
Visualize_SSV2(adata = adata[index], coord = SpaOTsc, title = 'SpaOTsc')
Visualize_SSV2(adata = adata[index], coord = SpaOTsc, title = 'SpaOTsc', legend = legend)

LR = pd.read_csv('LR/pred_' + str(i) + '.csv', header = None, index_col = 0).values
LR = RePolarTrans(ReMMNorm(RTheta, LR))
Visualize_SSV2(adata = adata[index], coord = LR, title = 'LR')
Visualize_SSV2(adata = adata[index], coord = LR, title = 'LR', legend = legend)

# %%
i = 0
index = test_indices[i]




SILE = pd.read_csv('SILE/pred_' + str(i) + '.csv', header = None, index_col = 0).values
SILE = RePolarTrans(ReMMNorm(RTheta, SILE))


novosparc = np.load('novosparc/pred_full_' + str(i) + '.npy')
novosparc = np.matmul(novosparc, Y[train_indices[i]]) * novosparc.shape[0]
Visualize1(adata = adata[index], coord = novosparc, title = 'Novosparc', legend = legend)

SpaOTsc = np.load('SpaOTsc/pred_' + str(i) + '.npy')
SpaOTsc = np.matmul(SpaOTsc, Y[train_indices[i]]) * SpaOTsc.shape[0]
Visualize1(adata = adata[index], coord = SpaOTsc, title = 'SpaOTsc', legend = legend)

LR = pd.read_csv('LR/pred_' + str(i) + '.csv', header = None, index_col = 0).values
LR = RePolarTrans(ReMMNorm(RTheta, LR))
Visualize1(adata = adata[index], coord = LR, lim = False, title = 'LR', legend = legend)
